# %%
import csv
import os
import re
import csv
from collections import Counter
from difflib import SequenceMatcher
from sklearn.feature_extraction.text import TfidfVectorizer
from utils import genius_utils_v3 as genius_utils

# %%
# Setup Genius API client
# Make sure you create a file called ".env" with contents being the same as ".env.example," but include your API key
# An API key can be obtained for free from https://genius.com/api-clients
genius = genius_utils.setup_genius_client()

# Run the pipeline for a sample artist
results = genius_utils.get_clean_explicit_pairs(genius, "Eminem", max_songs=100, debug=False)

for r in results:
    print(f"\n {r['base_title']}")
    print(f"  - Explicit: {r['explicit'][0]} → {r['explicit'][2]}")
    print(f"  - Clean:    {r['clean'][0]} → {r['clean'][2]}")
# Out:
# c:\Users\Jared\anaconda3\envs\pytorch\Lib\site-packages\lyricsgenius\genius.py:589: FutureWarning: The constructor signature will change in a future version. It will change to Song(lyrics, body) instead of Song(client, json_dict, lyrics).
#   song = Song(self, song_info, lyrics)
# INFO:utils.genius_utils_v3:Scanning: Rap God
# c:\Users\Jared\anaconda3\envs\pytorch\Lib\site-packages\lyricsgenius\genius.py:468: FutureWarning: The constructor signature will change in a future version. It will change to Song(lyrics, body) instead of Song(client, json_dict, lyrics).
#   song = Song(self, song_info, lyrics)
# INFO:utils.genius_utils_v3:Scanning: Lose Yourself
# INFO:utils.genius_utils_v3:Scanning: Mockingbird
# INFO:utils.genius_utils_v3:Scanning: Without Me
# INFO:utils.genius_utils_v3:Scanning: The Real Slim Shady
# INFO:utils.genius_utils_v3:Scanning: Stan
# INFO:utils.genius_utils_v3:Scanning: Killshot
# INFO:utils.genius_utils_v3:Scanning: Godzilla
# INFO:utils.genius_utils_v3:Scanning: Houdini
# INFO:utils.genius_utils_v3:Scanning: The Monster
# INFO:utils.genius_utils_v3:Scanning: Superman
# INFO:utils.genius_utils_v3:Scanning: Lucky You
# INFO:utils.genius_utils_v3:Scanning: ’Till I Collapse
# INFO:utils.genius_utils_v3:Scanning: The Ringer
# INFO:utils.genius_utils_v3:Scanning: Love the Way You Lie
# INFO:utils.genius_utils_v3:Scanning: Venom
# INFO:utils.genius_utils_v3:Scanning: River
# INFO:utils.genius_utils_v3:Scanning: 8 Mile: B-Rabbit vs Papa Doc
# INFO:utils.genius_utils_v3:Scanning: Not Alike
# INFO:utils.genius_utils_v3:Scanning: Cleanin’ Out My Closet
# INFO:utils.genius_utils_v3:Scanning: Berzerk
# INFO:utils.genius_utils_v3:Scanning: Fall
# INFO:utils.genius_utils_v3:Scanning: Beautiful
# INFO:utils.genius_utils_v3:Scanning: The Way I Am
# INFO:utils.genius_utils_v3:Scanning: When I’m Gone
# INFO:utils.genius_utils_v3:Scanning: My Name Is
# INFO:utils.genius_utils_v3:Scanning: Kamikaze
# INFO:utils.genius_utils_v3:Scanning: Bad Guy
# INFO:utils.genius_utils_v3:Scanning: Walk on Water
# INFO:utils.genius_utils_v3:Scanning: Not Afraid
# INFO:utils.genius_utils_v3:Scanning: Sing for the Moment
# INFO:utils.genius_utils_v3:Scanning: No Love
# INFO:utils.genius_utils_v3:Scanning: Like Toy Soldiers
# INFO:utils.genius_utils_v3:Scanning: Kim
# INFO:utils.genius_utils_v3:Scanning: Headlights
# INFO:utils.genius_utils_v3:Scanning: Shake That
# INFO:utils.genius_utils_v3:Scanning: Greatest
# INFO:utils.genius_utils_v3:Scanning: Survival
# INFO:utils.genius_utils_v3:Scanning: Kill You
# INFO:utils.genius_utils_v3:Scanning: Marshall Mathers
# INFO:utils.genius_utils_v3:Scanning: Criminal
# INFO:utils.genius_utils_v3:Scanning: Space Bound
# INFO:utils.genius_utils_v3:Scanning: Love Game
# INFO:utils.genius_utils_v3:Scanning: Unaccommodating
# INFO:utils.genius_utils_v3:Scanning: Legacy
# INFO:utils.genius_utils_v3:Scanning: Gnat
# INFO:utils.genius_utils_v3:Scanning: White America
# INFO:utils.genius_utils_v3:Scanning: I’m Back
# INFO:utils.genius_utils_v3:Scanning: FACK
# INFO:utils.genius_utils_v3:Scanning: Guts Over Fear
# INFO:utils.genius_utils_v3:Scanning: Fuel
# INFO:utils.genius_utils_v3:Scanning: Tobey
# INFO:utils.genius_utils_v3:Scanning: Ass Like That
# INFO:utils.genius_utils_v3:Scanning: 8 Mile
# INFO:utils.genius_utils_v3:Scanning: Role Model
# INFO:utils.genius_utils_v3:Scanning: Guilty Conscience
# INFO:utils.genius_utils_v3:Scanning: Business
# INFO:utils.genius_utils_v3:Scanning: Just Don’t Give a Fuck
# INFO:utils.genius_utils_v3:Scanning: Hailie’s Song
# INFO:utils.genius_utils_v3:Scanning: Darkness
# INFO:utils.genius_utils_v3:Scanning: Evil Twin
# INFO:utils.genius_utils_v3:Scanning: Believe
# INFO:utils.genius_utils_v3:Scanning: Just Lose It
# INFO:utils.genius_utils_v3:Scanning: Stronger Than I Was
# INFO:utils.genius_utils_v3:Scanning: Detroit Vs. Everybody
# INFO:utils.genius_utils_v3:Scanning: Untouchable
# INFO:utils.genius_utils_v3:Scanning: You Gon’ Learn
# INFO:utils.genius_utils_v3:Scanning: Beautiful Pain
# INFO:utils.genius_utils_v3:Scanning: So Much Better
# INFO:utils.genius_utils_v3:Scanning: The Warning
# INFO:utils.genius_utils_v3:Scanning: Chloraseptic (Remix)
# INFO:utils.genius_utils_v3:Scanning: Infinite
# INFO:utils.genius_utils_v3:Scanning: Zeus
# INFO:utils.genius_utils_v3:Scanning: Drug Ballad
# INFO:utils.genius_utils_v3:Scanning: Rhyme or Reason
# INFO:utils.genius_utils_v3:Scanning: Stepping Stone
# INFO:utils.genius_utils_v3:Scanning: Habits
# INFO:utils.genius_utils_v3:Scanning: Bitch Please 2
# INFO:utils.genius_utils_v3:Scanning: Campaign Speech
# INFO:utils.genius_utils_v3:Scanning: Kings Never Die
# INFO:utils.genius_utils_v3:Scanning: Premonition (Intro)
# INFO:utils.genius_utils_v3:Scanning: Soldier
# INFO:utils.genius_utils_v3:Scanning: Wicked Ways
# INFO:utils.genius_utils_v3:Scanning: Good Guy
# INFO:utils.genius_utils_v3:Scanning: Asshole
# INFO:utils.genius_utils_v3:Scanning: So Far...
# INFO:utils.genius_utils_v3:Scanning: Square Dance
# INFO:utils.genius_utils_v3:Scanning: Brain Damage
# INFO:utils.genius_utils_v3:Scanning: Normal
# INFO:utils.genius_utils_v3:Scanning: Under the Influence
# INFO:utils.genius_utils_v3:Scanning: Phenomenal
# INFO:utils.genius_utils_v3:Scanning: Offended
# INFO:utils.genius_utils_v3:Scanning: Brainless
# INFO:utils.genius_utils_v3:Scanning: My Dad’s Gone Crazy
# INFO:utils.genius_utils_v3:Scanning: Antichrist
# INFO:utils.genius_utils_v3:Scanning: My Darling
# INFO:utils.genius_utils_v3:Scanning: Rock Bottom
# INFO:utils.genius_utils_v3:Scanning: Leaving Heaven
# INFO:utils.genius_utils_v3:Scanning: 25 to Life
# INFO:utils.genius_utils_v3:Scanning: Those Kinda Nights
#  Rap God
#   - Explicit: Rap God → https://genius.com/Eminem-rap-god-lyrics
#   - Clean:    Rap God (Clean) → https://genius.com/Eminem-rap-god-clean-lyrics
#
#  Without Me
#   - Explicit: Without Me → https://genius.com/Eminem-without-me-lyrics
#   - Clean:    Without Me (Clean Version) → https://genius.com/Eminem-without-me-clean-version-lyrics
#
#  The Real Slim Shady
#   - Explicit: The Real Slim Shady → https://genius.com/Eminem-the-real-slim-shady-lyrics
#   - Clean:    The Real Slim Shady (Clean) → https://genius.com/Eminem-the-real-slim-shady-clean-lyrics
#
#  Stan
#   - Explicit: Stan → https://genius.com/Eminem-stan-lyrics
#   - Clean:    Stan (Clean) → https://genius.com/Eminem-stan-clean-lyrics
#
#  Godzilla
#   - Explicit: Godzilla → https://genius.com/Eminem-godzilla-lyrics
#   - Clean:    Godzilla (Super Clean) → https://genius.com/Eminem-godzilla-super-clean-lyrics
#
#  Superman
#   - Explicit: Superman → https://genius.com/Eminem-superman-lyrics
#   - Clean:    Superman (Clean Radio Edit) → https://genius.com/Eminem-superman-clean-radio-edit-lyrics
#
#  Beautiful
#   - Explicit: Beautiful → https://genius.com/Eminem-beautiful-lyrics
#   - Clean:    Beautiful (Radio Edit) → https://genius.com/Eminem-beautiful-radio-edit-lyrics
#
#  My Name Is
#   - Explicit: My Name Is → https://genius.com/Eminem-my-name-is-lyrics
#   - Clean:    My Name Is (Slim Shady Radio Edit) → https://genius.com/Eminem-my-name-is-slim-shady-radio-edit-lyrics
#
#  Shake That
#   - Explicit: Shake That → https://genius.com/Eminem-shake-that-lyrics
#   - Clean:    Shake That (Clean/Edited Version) → https://genius.com/Eminem-shake-that-clean-edited-version-lyrics
#
#  Marshall Mathers
#   - Explicit: Marshall Mathers → https://genius.com/Eminem-marshall-mathers-lyrics
#   - Clean:    The Real Slim Shady (Clean) → https://genius.com/Eminem-the-real-slim-shady-clean-lyrics
#
#  FACK
#   - Explicit: FACK → https://genius.com/Eminem-fack-lyrics
#   - Clean:    Just Don’t Give a Fuck (Clean Edit) → https://genius.com/Eminem-just-dont-give-a-fuck-clean-edit-lyrics
#
#  Role Model
#   - Explicit: Role Model → https://genius.com/Eminem-role-model-lyrics
#   - Clean:    Role Model (Clean Version) → https://genius.com/Eminem-role-model-clean-version-lyrics
#
#  Guilty Conscience
#   - Explicit: Guilty Conscience → https://genius.com/Eminem-guilty-conscience-lyrics
#   - Clean:    Guilty Conscience (Radio Extra Clean W/New Hook) → https://genius.com/Eminem-guilty-conscience-radio-extra-clean-w-new-hook-lyrics
#
#  Just Don’t Give a Fuck
#   - Explicit: Just Don’t Give a Fuck → https://genius.com/Eminem-just-dont-give-a-fuck-lyrics
#   - Clean:    Just Don’t Give a Fuck (Clean Edit) → https://genius.com/Eminem-just-dont-give-a-fuck-clean-edit-lyrics
#
#  Soldier
#   - Explicit: Soldier → https://genius.com/Eminem-soldier-lyrics
#   - Clean:    Soldier (Clean Version) → https://genius.com/Eminem-soldier-clean-version-lyrics

# %%
for pair in results:
    # Only save if both versions exist
    if not pair.get("explicit") or not pair.get("clean"):
        continue

    title_base = pair["base_title"]
    
    # Extract raw lyrics from both
    raw_explicit = pair["explicit"][1]
    raw_clean = pair["clean"][1]

    # Clean and strip headers
    intermediate_explicit = genius_utils.clean_lyrics_text(raw_explicit)
    intermediate_clean = genius_utils.clean_lyrics_text(raw_clean)

    # Final clean: remove punctuation + blank lines
    cleaned_explicit = genius_utils.remove_punctuation_and_blank_lines(intermediate_explicit)
    cleaned_clean = genius_utils.remove_punctuation_and_blank_lines(intermediate_clean)

    # Save to .txt files
    genius_utils.save_raw_and_cleaned_lyrics(title_base, "explicit", raw_explicit, cleaned_explicit)
    genius_utils.save_raw_and_cleaned_lyrics(title_base, "clean", raw_clean, cleaned_clean)

    # Optional print
    print(f"✅ Saved: {title_base}")
# Out:
# ✅ Saved: Rap God
# ✅ Saved: Without Me
# ✅ Saved: The Real Slim Shady
# ✅ Saved: Stan
# ✅ Saved: Godzilla
# ✅ Saved: Superman
# ✅ Saved: Beautiful
# ✅ Saved: My Name Is
# ✅ Saved: Shake That
# ✅ Saved: Marshall Mathers
# ✅ Saved: FACK
# ✅ Saved: Role Model
# ✅ Saved: Guilty Conscience
# ✅ Saved: Just Don’t Give a Fuck
# ✅ Saved: Soldier

# %%
def merge_compounds(reference_tokens, target_tokens, max_compound_len=4):
    """
    Replace sequences of 2–max_compound_len tokens in target_tokens with compound
    forms found in reference_tokens.
    """
    i = 0
    while i < len(target_tokens):
        merged = False
        for n in range(max_compound_len, 1, -1):
            if i + n > len(target_tokens):
                continue
            phrase = target_tokens[i:i+n]
            candidate = ''.join(phrase)
            if candidate in reference_tokens:
                target_tokens[i:i+n] = [candidate]
                merged = True
                break
        if not merged:
            i += 1
    return target_tokens

def normalize_and_export(explicit_path, clean_path):
    # Read input files
    with open(explicit_path, 'r', encoding='utf-8') as f:
        explicit_tokens = f.read().split()

    with open(clean_path, 'r', encoding='utf-8') as f:
        clean_tokens = f.read().split()

    # Normalize each using the other
    clean_tokens = merge_compounds(explicit_tokens, clean_tokens)
    explicit_tokens = merge_compounds(clean_tokens, explicit_tokens)

    # Determine output file names
    explicit_out = os.path.splitext(explicit_path)[0] + "_normalized.txt"
    clean_out = os.path.splitext(clean_path)[0] + "_normalized.txt"

    # Write normalized files
    with open(explicit_out, 'w', encoding='utf-8') as f:
        f.write(' '.join(explicit_tokens))

    with open(clean_out, 'w', encoding='utf-8') as f:
        f.write(' '.join(clean_tokens))

    print(f"Normalized files saved as:\n  {explicit_out}\n  {clean_out}")

# %%
test_songs = ["Beautiful", "FACK","Guilty Conscience", "Just Don’t Give a Fuck", "Marshall Mathers", "My Name Is", "Role Model", "Shake That", "Soldier", "Godzilla", "Stan", "Superman", "Rap God", "The Real Slim Shady", "Without Me"]

# %%
for test_song in test_songs:
    normalize_and_export(    
    explicit_path="lyrics/clean/"+test_song+"__explicit_cleaned.txt",
    clean_path="lyrics/clean/"+test_song+"__clean_cleaned.txt",
)
# Out:
# Normalized files saved as:
#   lyrics/clean/Beautiful__explicit_cleaned_normalized.txt
#   lyrics/clean/Beautiful__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/FACK__explicit_cleaned_normalized.txt
#   lyrics/clean/FACK__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Guilty Conscience__explicit_cleaned_normalized.txt
#   lyrics/clean/Guilty Conscience__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Just Don’t Give a Fuck__explicit_cleaned_normalized.txt
#   lyrics/clean/Just Don’t Give a Fuck__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Marshall Mathers__explicit_cleaned_normalized.txt
#   lyrics/clean/Marshall Mathers__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/My Name Is__explicit_cleaned_normalized.txt
#   lyrics/clean/My Name Is__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Role Model__explicit_cleaned_normalized.txt
#   lyrics/clean/Role Model__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Shake That__explicit_cleaned_normalized.txt
#   lyrics/clean/Shake That__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Soldier__explicit_cleaned_normalized.txt
#   lyrics/clean/Soldier__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Godzilla__explicit_cleaned_normalized.txt
#   lyrics/clean/Godzilla__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Stan__explicit_cleaned_normalized.txt
#   lyrics/clean/Stan__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Superman__explicit_cleaned_normalized.txt
#   lyrics/clean/Superman__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Rap God__explicit_cleaned_normalized.txt
#   lyrics/clean/Rap God__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/The Real Slim Shady__explicit_cleaned_normalized.txt
#   lyrics/clean/The Real Slim Shady__clean_cleaned_normalized.txt
# Normalized files saved as:
#   lyrics/clean/Without Me__explicit_cleaned_normalized.txt
#   lyrics/clean/Without Me__clean_cleaned_normalized.txt

# %%
def clean_diff_variants(diffs):
    """
    Cleans diff pairs by removing:
    - '-in' vs '-ing' endings (e.g. killin vs killing)
    - past tense vs base verb (e.g. asked vs ask)
    - common misspellings/confusables (e.g. then vs than, woman vs women)
    - diff pairs where explicit is blank
    Returns a cleaned list of diffs.
    """
    filtered_diffs = []

    CONFUSABLE_PAIRS = {
        ("then", "than"),
        ("your", "youre"),
        ("there", "their"),
        ("its", "its"),  # since apostrophes are removed
        ("affect", "effect"),
        ("to", "too"),
        ("of", "off"),
        ("woman", "women"),
        ("womans", "womens"),
        ("man", "men"),
        ("mans", "mens")
    }

    for explicit_phrase, clean_phrase, aligned_word in diffs:
        explicit_words = explicit_phrase.split()
        clean_words = clean_phrase.split()

        # Skip if explicit is blank or only spaces
        if not explicit_words:
            continue

        set_explicit = set(explicit_words)
        set_clean = set(clean_words)

        to_remove_explicit = set()
        to_remove_clean = set()

        # 1. Remove -in vs -ing pairs
        for ew in set_explicit:
            if ew.endswith("in") and (ew + "g") in set_clean:
                to_remove_explicit.add(ew)
                to_remove_clean.add(ew + "g")
        for cw in set_clean:
            if cw.endswith("in") and (cw + "g") in set_explicit:
                to_remove_clean.add(cw)
                to_remove_explicit.add(cw + "g")

        # 2. Remove past tense vs base form (naive ed-stripping)
        for ew in set_explicit:
            if ew.endswith("ed"):
                base = ew[:-2]
                if base in set_clean:
                    to_remove_explicit.add(ew)
                    to_remove_clean.add(base)
        for cw in set_clean:
            if cw.endswith("ed"):
                base = cw[:-2]
                if base in set_explicit:
                    to_remove_clean.add(cw)
                    to_remove_explicit.add(base)

        # 3. Remove confusables
        for a, b in CONFUSABLE_PAIRS:
            if a in set_explicit and b in set_clean:
                to_remove_explicit.add(a)
                to_remove_clean.add(b)
            elif b in set_explicit and a in set_clean:
                to_remove_explicit.add(b)
                to_remove_clean.add(a)

        # Final cleanup
        new_explicit = [w for w in explicit_words if w not in to_remove_explicit]
        new_clean = [w for w in clean_words if w not in to_remove_clean]

        if new_explicit or new_clean:
            filtered_diffs.append((' '.join(new_explicit), ' '.join(new_clean), aligned_word))

    print(f"✅ Filtered {len(diffs) - len(filtered_diffs)} trivial or empty diffs")
    return filtered_diffs

# %%
def tokenize(text):
    return re.findall(r"\w+", text.lower())

def jaccard_similarity(list1, list2):
    set1, set2 = set(list1), set(list2)
    intersection = set1 & set2
    union = set1 | set2
    return len(intersection) / len(union) if union else 0

def find_realign_point(exp_tokens, clean_tokens, exp_idx, clean_idx, window=20):
    for offset in range(window):
        for delta in range(-2, 3):  # small shifts
            e_pos = exp_idx + offset
            c_pos = clean_idx + offset + delta
            if e_pos + 1 < len(exp_tokens) and c_pos + 1 < len(clean_tokens):
                if (exp_tokens[e_pos], exp_tokens[e_pos + 1]) == (clean_tokens[c_pos], clean_tokens[c_pos + 1]):
                    return (e_pos, c_pos, f"{exp_tokens[e_pos]} {exp_tokens[e_pos+1]}")

    # fallback to one-word match
    for offset in range(window):
        e_pos = exp_idx + offset
        if e_pos >= len(exp_tokens):  # prevent out-of-bounds
            break
        word = exp_tokens[e_pos]

        for j in range(clean_idx, min(clean_idx + window, len(clean_tokens))):
            if clean_tokens[j] == word:
                # ensure context window is within bounds
                exp_context = exp_tokens[e_pos + 1 : min(e_pos + 11, len(exp_tokens))]
                clean_context = clean_tokens[j + 1 : min(j + 11, len(clean_tokens))]
                sim = jaccard_similarity(exp_context, clean_context)
                if sim > 0.3:
                    return (e_pos, j, word)

    return (None, None, None)


def is_trivial_diff(exp, clean):
    HOMOPHONES = {"pfft", "pft", "bzz", "kshh", "eugh", "ugh", "ah", "huh", "shhh", "sh"}
    return not exp and not clean or exp in HOMOPHONES or clean in HOMOPHONES

def strict_compare_lyrics(explicit_path, clean_path, out_csv="my_diffs.csv"):
    with open(explicit_path, "r", encoding="utf-8") as f:
        explicit = tokenize(f.read())
    with open(clean_path, "r", encoding="utf-8") as f:
        clean = tokenize(f.read())

    i = j = 0
    diffs = []

    while i < len(explicit) and j < len(clean):
        if explicit[i] == clean[j]:
            i += 1
            j += 1
        else:
            exp_start, clean_start = i, j

            # find next alignment point
            match_i, match_j, matched_word = find_realign_point(explicit, clean, i, j)

            if match_i is None:
                break

            explicit_diff = explicit[exp_start:match_i]
            clean_diff = clean[clean_start:match_j]

            if not is_trivial_diff(' '.join(explicit_diff), ' '.join(clean_diff)):
                diffs.append((' '.join(explicit_diff), ' '.join(clean_diff), matched_word))

            i = match_i
            j = match_j
    
    diffs = clean_diff_variants(diffs)
    print(f"✅ Comparison complete. Total differences found: {len(diffs)}")
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Explicit", "Clean", "Aligned At"])
        writer.writerows(diffs)

    # Print differences
    print("Now looking at song:",test_song)
    for exp, clean, match in diffs:
        print(f"EXPLICIT: {exp}\nCLEAN:    {clean}\nALIGN:    {match}\n")

    return diffs

# %%
for test_song in test_songs:
    strict_compare_lyrics("./lyrics/clean/"+test_song+"__explicit_cleaned_normalized.txt", "./lyrics/clean/"+test_song+"__clean_cleaned_normalized.txt")
# Out:
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 9
# Now looking at song: Beautiful
# EXPLICIT: via mtv
# CLEAN:
# ALIGN:    lately been
#
# EXPLICIT: fucking
# CLEAN:
# ALIGN:    depressed just
#
# EXPLICIT: fucked
# CLEAN:    f
# ALIGN:    just stay
#
# EXPLICIT: fucked
# CLEAN:    f
# ALIGN:    just stay
#
# EXPLICIT: fuckin
# CLEAN:    f
# ALIGN:    man servant
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    laugh every
#
# EXPLICIT: goddamn
# CLEAN:
# ALIGN:    unfortunately am
#
# EXPLICIT: fucked
# CLEAN:    f
# ALIGN:    just stay
#
# EXPLICIT: fucked
# CLEAN:    f
# ALIGN:    just stay
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 0
# Now looking at song: FACK
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 11
# Now looking at song: Guilty Conscience
# EXPLICIT: twentythree
# CLEAN:    23
# ALIGN:    years old
#
# EXPLICIT: damn
# CLEAN:
# ALIGN:    going fucking
#
# EXPLICIT: gotta
# CLEAN:    cant
# ALIGN:    take this
#
# EXPLICIT: shit
# CLEAN:    more
# ALIGN:    cant take
#
# EXPLICIT: holmes
# CLEAN:    homes
# ALIGN:    but way
#
# EXPLICIT: fuck
# CLEAN:    bump
# ALIGN:    that that
#
# EXPLICIT: shoot that bitch
# CLEAN:    hit that lick
# ALIGN:    can afford
#
# EXPLICIT: shit
# CLEAN:    hit
# ALIGN:    are that
#
# EXPLICIT: why give fuck if dies
# CLEAN:    whyd care if scare death
# ALIGN:    are that
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    really think
#
# EXPLICIT: shit
# CLEAN:    lick
# ALIGN:    stop drop
#
# ✅ Filtered 3 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 43
# Now looking at song: Just Don’t Give a Fuck
# EXPLICIT: woah aget
# CLEAN:    whoa get
# ALIGN:    hands air
#
# EXPLICIT: becausea
# CLEAN:    because
# ALIGN:    this is
#
# EXPLICIT: bes
# CLEAN:    beez
# ALIGN:    brothers representin
#
# EXPLICIT: m80
# CLEAN:    meighty
# ALIGN:    little like
#
# EXPLICIT: motherfucker
# CLEAN:    motherfer
# ALIGN:    bit style
#
# EXPLICIT: gon
# CLEAN:    gonna
# ALIGN:    sell two
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    while comin
#
# EXPLICIT: ass bitch
# CLEAN:    b
# ALIGN:    comin out
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    out like
#
# EXPLICIT: motherfuckin
# CLEAN:    motherfin
# ALIGN:    throat worse
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    world like
#
# EXPLICIT: fuck talkin that shit
# CLEAN:    f talkin thats
# ALIGN:    behind back
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    put tape
#
# EXPLICIT: shit
# CLEAN:    s
# ALIGN:    is wack
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    but see
#
# EXPLICIT: stole
# CLEAN:    stoned
# ALIGN:    snuffed cause
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    nicer than
#
# EXPLICIT: diss
# CLEAN:    dis
# ALIGN:    reason colder
#
# EXPLICIT: diss
# CLEAN:    dis
# ALIGN:    magazine still
#
# EXPLICIT: while
# CLEAN:    but
# ALIGN:    form like
#
# EXPLICIT: mm
# CLEAN:    eminem
# ALIGN:    was old
#
# EXPLICIT: shit outta
# CLEAN:    s out
# ALIGN:    proportion looniest
#
# EXPLICIT: fuckin
# CLEAN:    fin
# ALIGN:    trash can
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    world like
#
# EXPLICIT: fuck talkin that shit
# CLEAN:    f talkin thats
# ALIGN:    behind back
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    put tape
#
# EXPLICIT: shit
# CLEAN:    s
# ALIGN:    is wack
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    but see
#
# EXPLICIT: finna
# CLEAN:    fittin
# ALIGN:    get stuck
#
# EXPLICIT: stole
# CLEAN:    stoned
# ALIGN:    snuffed cause
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    somebody let
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    droppin jewel
#
# EXPLICIT: motherfuckin
# CLEAN:    motherfin
# ALIGN:    style just
#
# EXPLICIT: bitches
# CLEAN:    bes
# ALIGN:    sick naggin
#
# EXPLICIT: bitchin
# CLEAN:    bin
# ALIGN:    while washin
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    world like
#
# EXPLICIT: fuck talkin that shit
# CLEAN:    f talkin thats
# ALIGN:    behind back
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    put tape
#
# EXPLICIT: shit
# CLEAN:    s
# ALIGN:    is wack
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    but see
#
# EXPLICIT: finna
# CLEAN:    fittin
# ALIGN:    get stuck
#
# EXPLICIT: stole
# CLEAN:    stoned
# ALIGN:    snuffed cause
#
# EXPLICIT: fuck shit fuck everybody outsiderz pacewon
# CLEAN:    f hey f that outsiders pace one
# ALIGN:    young zee
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 0
# Now looking at song: Marshall Mathers
# ✅ Filtered 5 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 32
# Now looking at song: My Name Is
# EXPLICIT: violence yeah
# CLEAN:    primus
# ALIGN:    yeah wanna
#
# EXPLICIT: yeah
# CLEAN:
# ALIGN:    try cid
#
# EXPLICIT: fucked
# CLEAN:    messed
# ALIGN:    up worse
#
# EXPLICIT: tryna
# CLEAN:    trying
# ALIGN:    get head
#
# EXPLICIT: then
# CLEAN:
# ALIGN:    whys face
#
# EXPLICIT: 12
# CLEAN:    twelve
# ALIGN:    felt like
#
# EXPLICIT: someone else cause hung original self from top bunk belt got pissed
# CLEAN:    caged elf who stayed one space chasing tail got ticked
# ALIGN:    off ripped
#
# EXPLICIT: tits off smacked hard knocked clothes backwards like kris kross smoke fat pound grass fall ass
# CLEAN:    lips off kissed said aint know silicone was supposed be this soft bout pass out crash fall grass
# ALIGN:    faster than
#
# EXPLICIT: bitch
# CLEAN:    man
# ALIGN:    who sat
#
# EXPLICIT: slut
# CLEAN:    lady
# ALIGN:    shady wait
#
# EXPLICIT: fuck god sent piss
# CLEAN:    damn dre sent tick
# ALIGN:    world off
#
# EXPLICIT: 35
# CLEAN:    thirtyfive
# ALIGN:    smacked face
#
# EXPLICIT: stapled nuts stack paper ow
# CLEAN:    told change grade paper now
# ALIGN:    walked strip
#
# EXPLICIT: flashed
# CLEAN:    served
# ALIGN:    bartender then
#
# EXPLICIT: stuck dick
# CLEAN:    walked out
# ALIGN:    tip cup
#
# EXPLICIT: 99
# CLEAN:    ninetynine
# ALIGN:    percent life
#
# EXPLICIT: dope than damn
# CLEAN:    than what
# ALIGN:    told grow
#
# EXPLICIT: drugs
# CLEAN:
# ALIGN:    name after
#
# EXPLICIT: thank
# CLEAN:    here mom
# ALIGN:    know blew
#
# EXPLICIT: get
# CLEAN:    have
# ALIGN:    autograph signed
#
# EXPLICIT: asshole
# CLEAN:
# ALIGN:    hi name
#
# EXPLICIT: who
# CLEAN:    what
# ALIGN:    name is
#
# EXPLICIT: who
# CLEAN:    what
# ALIGN:    name is
#
# EXPLICIT: fuck that
# CLEAN:
# ALIGN:    have be
#
# EXPLICIT: huh yup am or
# CLEAN:    ohh am or
# ALIGN:    can barely
#
# EXPLICIT: vodka
# CLEAN:    koolaid
# ALIGN:    dare drive
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    anything that
#
# EXPLICIT: come here
# CLEAN:
# ALIGN:    when was
#
# EXPLICIT: shoot head bang cause
# CLEAN:    tap head till
# ALIGN:    mad way
#
# EXPLICIT: tell that slit throat this dream had
# CLEAN:    ask if bought porno mag see ad
# ALIGN:    hi name
#
# EXPLICIT: who
# CLEAN:    what
# ALIGN:    name is
#
# EXPLICIT: who
# CLEAN:    what
# ALIGN:    name is
#
# ✅ Filtered 4 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 26
# Now looking at song: Role Model
# EXPLICIT: okay going attempt drown can try this home can be just like mic check two recordin
# CLEAN:
# ALIGN:    cancerous
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    answer this
#
# EXPLICIT: strangle death then choke again break fuckin legs til bones poke through skin beef ima
# CLEAN:    hellspawn dropping stealth bomb six mics source borrowed one from lls arm beef
# ALIGN:    even score
#
# EXPLICIT: blunted off funny homegrown cause when smoke out hit trees
# CLEAN:    funny off twenty nodoz hop snowboard hit tree
# ALIGN:    harder than
#
# EXPLICIT: did drugs
# CLEAN:    get buzzed
# ALIGN:    that would
#
# EXPLICIT: fucked
# CLEAN:    butt
# ALIGN:    more than
#
# EXPLICIT: ripped fuckin
# CLEAN:    took freaking
# ALIGN:    tonsils out
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    nerves hurt
#
# EXPLICIT: come here motherfucker
# CLEAN:
# ALIGN:    every
#
# EXPLICIT: les
# CLEAN:    less
# ALIGN:    follow exactly
#
# EXPLICIT: smoke weed take pills drop
# CLEAN:    talk back fake sick get
# ALIGN:    out school
#
# EXPLICIT: kill people drink jump behind wheel like was still legal
# CLEAN:    steal from people dont think before somethin thats illegal
# ALIGN:    dumb enough
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    can be
#
# EXPLICIT: die from overdose
# CLEAN:    fry from overload
# ALIGN:    dig up
#
# EXPLICIT: supposed
# CLEAN:    posed
# ALIGN:    teach kids
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    grow up
#
# EXPLICIT: mustve
# CLEAN:    must have
# ALIGN:    been ron
#
# EXPLICIT: orgy hold killed both then
# CLEAN:    session hold did both
# ALIGN:    smeared blood
#
# EXPLICIT: did
# CLEAN:
# ALIGN:    mind wont
#
# EXPLICIT: bout
# CLEAN:    about
# ALIGN:    as normal
#
# EXPLICIT: high
# CLEAN:    fried
# ALIGN:    or nuts
#
# EXPLICIT: shit
# CLEAN:    hit
# ALIGN:    over bought
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    grow up
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    grow up
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    grow up
#
# EXPLICIT: wanna
# CLEAN:    want
# ALIGN:    grow up
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 45
# Now looking at song: Shake That
# EXPLICIT: bitch shit
# CLEAN:    chick
# ALIGN:    hey damn
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    flo bumpin
#
# EXPLICIT: buzzed
# CLEAN:    up
# ALIGN:    get drunk
#
# EXPLICIT: fucked
# CLEAN:    buzzed
# ALIGN:    up hit
#
# EXPLICIT: dick rubbed get fucked get sucked
# CLEAN:    big funs get rubbed sip up
# ALIGN:    get wasted
#
# EXPLICIT: shitfaceted
# CLEAN:    faceted
# ALIGN:    pasted plastered
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    gyrated hips
#
# EXPLICIT: some shit
# CLEAN:    somethin
# ALIGN:    two one
#
# EXPLICIT: pussy
# CLEAN:
# ALIGN:    like good
#
# EXPLICIT: tree smoke
# CLEAN:
# ALIGN:    much
#
# EXPLICIT: weed
# CLEAN:
# ALIGN:    wouldnt believe
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    than toilet
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    last night
#
# EXPLICIT: motherfuckin
# CLEAN:    mokin
# ALIGN:    mountaintop heard
#
# EXPLICIT: motherfuckers
# CLEAN:    mos
# ALIGN:    talk seen
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    off wall
#
# EXPLICIT: retarded
# CLEAN:    rrded
# ALIGN:    some girls
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    say every
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    come girl
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    girl shake
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    come girl
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    menace dentist
#
# EXPLICIT: bitches
# CLEAN:    chickens
# ALIGN:    some double
#
# EXPLICIT: es slip
# CLEAN:    these mix
# ALIGN:    bubbly finna
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    hummer truck
#
# EXPLICIT: retarded
# CLEAN:    rded
# ALIGN:    man told
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    sit crib
#
# EXPLICIT: slut
# CLEAN:    sl
# ALIGN:    would be
#
# EXPLICIT: slut
# CLEAN:    sl
# ALIGN:    hope dont
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    come girl
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    girl shake
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    come girl
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    shake that
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    bout have
#
# EXPLICIT: retarded
# CLEAN:    rded
# ALIGN:    some girls
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    say every
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    flo bumpin
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    comin home
#
# ✅ Filtered 1 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 1
# Now looking at song: Soldier
# EXPLICIT: shit
# CLEAN:
# ALIGN:    appealin willin
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 35
# Now looking at song: Godzilla
# EXPLICIT: swallow bottle alcohol
# CLEAN:
# ALIGN:    feel
#
# EXPLICIT: this bitch
# CLEAN:
# ALIGN:    possed up
#
# EXPLICIT: courvoisier hey ak
# CLEAN:    hey
# ALIGN:    melee finna
#
# EXPLICIT: lick
# CLEAN:
# ALIGN:    balls had
#
# EXPLICIT: pissed
# CLEAN:
# ALIGN:    off impossible
#
# EXPLICIT: risperdal
# CLEAN:
# ALIGN:    voices whisper
#
# EXPLICIT: pistol guy missile
# CLEAN:    guy
# ALIGN:    launcher just
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    screw off
#
# EXPLICIT: fifth vodka
# CLEAN:
# ALIGN:    when
#
# EXPLICIT: twist top bottle
# CLEAN:
# ALIGN:    monster
#
# EXPLICIT: motherfuckin finger finger prostate exam xam
# CLEAN:
# ALIGN:    how
#
# EXPLICIT: spazzin
# CLEAN:
# ALIGN:    out only
#
# EXPLICIT: blades chainsaw
# CLEAN:
# ALIGN:    cause caught
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    got racks
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    player too
#
# EXPLICIT: motherfuckin
# CLEAN:
# ALIGN:    stingy cher
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    marry if
#
# EXPLICIT: face genital
# CLEAN:
# ALIGN:    area original
#
# EXPLICIT: cristhian
# CLEAN:    christian
# ALIGN:    rivera cause
#
# EXPLICIT: dick
# CLEAN:
# ALIGN:    harry carry
#
# EXPLICIT: motherfuckin
# CLEAN:
# ALIGN:    dictionary swearing
#
# EXPLICIT: shits
# CLEAN:    s
# ALIGN:    hilarious time
#
# EXPLICIT: bitches
# CLEAN:
# ALIGN:    obituary column
#
# EXPLICIT: trigger
# CLEAN:
# ALIGN:    happy pack
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    like apache
#
# EXPLICIT: eliminate
# CLEAN:
# ALIGN:    other words
#
# EXPLICIT: murderin
# CLEAN:
# ALIGN:    again nobody
#
# EXPLICIT: kill dump all fuckin
# CLEAN:
# ALIGN:    bodies
#
# EXPLICIT: kill or be killed killer
# CLEAN:
# ALIGN:    bee
#
# EXPLICIT: killer
# CLEAN:
# ALIGN:    within outta
#
# EXPLICIT: motherfucker
# CLEAN:
# ALIGN:    better duck
#
# EXPLICIT: dead
# CLEAN:
# ALIGN:    minute run
#
# EXPLICIT: fifth
# CLEAN:
# ALIGN:    percent bout
#
# EXPLICIT: fuckin finish bitch
# CLEAN:    finish
# ALIGN:    unfadable wanna
#
# EXPLICIT: blowin up
# CLEAN:
# ALIGN:    like inflatable
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 31
# Now looking at song: Stan
# EXPLICIT: grey
# CLEAN:    gray
# ALIGN:    but picture
#
# EXPLICIT: grey
# CLEAN:    gray
# ALIGN:    but picture
#
# EXPLICIT: probly
# CLEAN:    probably
# ALIGN:    was problem
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    whats been
#
# EXPLICIT: kill
# CLEAN:
# ALIGN:    over some
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    who didnt
#
# EXPLICIT: probly
# CLEAN:    probably
# ALIGN:    hear this
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    that did
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    did rawkus
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    was phat
#
# EXPLICIT: grey
# CLEAN:    gray
# ALIGN:    but picture
#
# EXPLICIT: fucked up
# CLEAN:
# ALIGN:    dont answer
#
# EXPLICIT: shitty
# CLEAN:
# ALIGN:    man like
#
# EXPLICIT: fuckin
# CLEAN:
# ALIGN:    idol wants
#
# EXPLICIT: beat
# CLEAN:
# ALIGN:    can relate
#
# EXPLICIT: shitty
# CLEAN:
# ALIGN:    day drift
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    else that
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    helps when
#
# EXPLICIT: sometimes even cut see how much bleeds
# CLEAN:
# ALIGN:    like
#
# EXPLICIT: grey
# CLEAN:    gray
# ALIGN:    but picture
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    been six
#
# EXPLICIT: word
# CLEAN:    wordi
# ALIGN:    dont deserve
#
# EXPLICIT: ninety
# CLEAN:    90
# ALIGN:    freeway hey
#
# EXPLICIT: drank fifth vodka
# CLEAN:
# ALIGN:    dare
#
# EXPLICIT: drownin
# CLEAN:
# ALIGN:    but didnt
#
# EXPLICIT: drownin
# CLEAN:
# ALIGN:    now too
#
# EXPLICIT: now
# CLEAN:    nowim
# ALIGN:    drowsy all
#
# EXPLICIT: hope cant
# CLEAN:
# ALIGN:    sleep dream
#
# EXPLICIT: hope cant
# CLEAN:
# ALIGN:    sleep scream
#
# EXPLICIT: hope conscience eats cant breathe without
# CLEAN:
# ALIGN:    see
#
# EXPLICIT: bitch tryna
# CLEAN:    tryin
# ALIGN:    talk hey
#
# ✅ Filtered 3 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 24
# Now looking at song: Superman
# EXPLICIT: ohooh
# CLEAN:
# ALIGN:    here save
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    make hurl
#
# EXPLICIT: hoes
# CLEAN:    girls
# ALIGN:    single bound
#
# EXPLICIT: bitch
# CLEAN:    trick
# ALIGN:    babysit make
#
# EXPLICIT: shit
# CLEAN:    spit
# ALIGN:    girl can
#
# EXPLICIT: muhfuckin slut
# CLEAN:    giddy little girl
# ALIGN:    face play
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    why ask
#
# EXPLICIT: dick
# CLEAN:    grits
# ALIGN:    get cash
#
# EXPLICIT: puss
# CLEAN:    looks
# ALIGN:    blew out
#
# EXPLICIT: bitch
# CLEAN:    trick
# ALIGN:    if died
#
# EXPLICIT: bitches
# CLEAN:    chickens
# ALIGN:    come saturday
#
# EXPLICIT: yeah
# CLEAN:
# ALIGN:    monday through
#
# EXPLICIT: fuckin
# CLEAN:    empty
# ALIGN:    runway cause
#
# EXPLICIT: hoes
# CLEAN:    girls
# ALIGN:    secret everybody
#
# EXPLICIT: fuckedbitch
# CLEAN:    fucked trick
# ALIGN:    what thats
#
# EXPLICIT: sluts
# CLEAN:    girls
# ALIGN:    how could
#
# EXPLICIT: bitches
# CLEAN:    chickens
# ALIGN:    come saturday
#
# EXPLICIT: fuckin
# CLEAN:    empty
# ALIGN:    runway cause
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    make hurl
#
# EXPLICIT: slap
# CLEAN:    bump
# ALIGN:    off that
#
# EXPLICIT: handprints
# CLEAN:    footprints
# ALIGN:    all across
#
# EXPLICIT: bitches
# CLEAN:    chickens
# ALIGN:    come saturday
#
# EXPLICIT: fuckin
# CLEAN:    empty
# ALIGN:    runway cause
#
# EXPLICIT: bitch
# CLEAN:    chick
# ALIGN:    make hurl
#
# ✅ Filtered 0 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 20
# Now looking at song: Rap God
# EXPLICIT: nutsack
# CLEAN:    wuusack
# ALIGN:    mc still
#
# EXPLICIT: motherfuckin
# CLEAN:    motherfuppin
# ALIGN:    table over
#
# EXPLICIT: faggots
# CLEAN:    feggats
# ALIGN:    crack half
#
# EXPLICIT: motherfuckin
# CLEAN:    motherfufkin
# ALIGN:    rock roll
#
# EXPLICIT: fags
# CLEAN:    tas
# ALIGN:    think all
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    are thinkin
#
# EXPLICIT: gaythats
# CLEAN:    guaythats
# ALIGN:    all say
#
# EXPLICIT: deepthroatin
# CLEAN:    deepthreenoh
# ALIGN:    out ramen
#
# EXPLICIT: kids
# CLEAN:    kws
# ALIGN:    from columbine
#
# EXPLICIT: ak47
# CLEAN:    asfertysewvn
# ALIGN:    revolver 9
#
# EXPLICIT: fuck
# CLEAN:    fww
# ALIGN:    that rhyme
#
# EXPLICIT: fuckin
# CLEAN:    fufkin
# ALIGN:    cornrows write
#
# EXPLICIT: fuck
# CLEAN:    uck
# ALIGN:    being normal
#
# EXPLICIT: fag
# CLEAN:    fwag
# ALIGN:    mayweathers pad
#
# EXPLICIT: motherfuckin
# CLEAN:    motherfufkin
# ALIGN:    audience feeling
#
# EXPLICIT: fuck
# CLEAN:    fufk
# ALIGN:    drunk satan
#
# EXPLICIT: fucking
# CLEAN:    f
# ALIGN:    wheel ima
#
# EXPLICIT: fuck
# CLEAN:    uck
# ALIGN:    lifes handin
#
# EXPLICIT: fuck
# CLEAN:    fauwk
# ALIGN:    am supposed
#
# EXPLICIT: retardbe
# CLEAN:    retarshbe
# ALIGN:    king think
#
# ✅ Filtered 9 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 17
# Now looking at song: The Real Slim Shady
# EXPLICIT: parents bedrooms
# CLEAN:    parents bedroom
# ALIGN:    sometimes wanna
#
# EXPLICIT: clitoris
# CLEAN:
# ALIGN:    is course
#
# EXPLICIT: cut
# CLEAN:
# ALIGN:    other people
#
# EXPLICIT: nope fuck fuck
# CLEAN:    beep beep
# ALIGN:    too think
#
# EXPLICIT: shit
# CLEAN:
# ALIGN:    christina aguilera
#
# EXPLICIT: head
# CLEAN:
# ALIGN:    first little
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    put blast
#
# EXPLICIT: vd
# CLEAN:
# ALIGN:    sick little
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    like who
#
# EXPLICIT: err just shit
# CLEAN:    just
# ALIGN:    better than
#
# EXPLICIT: ninety percent
# CLEAN:    90
# ALIGN:    rappers out
#
# EXPLICIT: valiums
# CLEAN:
# ALIGN:    funny cause
#
# EXPLICIT: home pinchin nurses asses when jacking off jergens jerking but this whole bag viagra isnt working
# CLEAN:    home
# ALIGN:    every
#
# EXPLICIT: ch puh or
# CLEAN:    or
# ALIGN:    lot circling
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    windows down
#
# EXPLICIT: out mind out
# CLEAN:    outta mind outta
# ALIGN:    control one
#
# EXPLICIT: fuck
# CLEAN:
# ALIGN:    lets all
#
# ✅ Filtered 3 trivial or empty diffs
# ✅ Comparison complete. Total differences found: 18
# Now looking at song: Without Me
# EXPLICIT: weed
# CLEAN:
# ALIGN:    mixed some
#
# EXPLICIT: now
# CLEAN:
# ALIGN:    stop debating
#
# EXPLICIT: rag ovulating
# CLEAN:
# ALIGN:    know that
#
# EXPLICIT: bum lips fuck that cum lips some tits
# CLEAN:    jump back jiggle hip wiggle bit
# ALIGN:    get ready
#
# EXPLICIT: shits
# CLEAN:    is
# ALIGN:    about get
#
# EXPLICIT: fuck
# CLEAN:    f
# ALIGN:    debbie now
#
# EXPLICIT: bitch
# CLEAN:
# ALIGN:    visionary vision
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    disaster such
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    back fix
#
# EXPLICIT: skin
# CLEAN:    nails
# ALIGN:    like splinter
#
# EXPLICIT: tisket tasket titfortat wit
# CLEAN:    atiskit ataskit tit tat
# ALIGN:    anybody whos
#
# EXPLICIT: this shit that shit
# CLEAN:    this that
# ALIGN:    chris kirkpatrick
#
# EXPLICIT: ass
# CLEAN:
# ALIGN:    kicked worse
#
# EXPLICIT: bastards
# CLEAN:
# ALIGN:    moby can
#
# EXPLICIT: fag blow
# CLEAN:    skag
# ALIGN:    dont know
#
# EXPLICIT: shit
# CLEAN:    man
# ALIGN:    just seems
#
# EXPLICIT: itd
# CLEAN:
# ALIGN:    be empty
#
# EXPLICIT: dei
# CLEAN:
# ALIGN:    hum
